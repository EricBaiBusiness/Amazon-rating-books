# %%
import pandas as pd

subset = pd.read_csv('subset.csv')
subset
# Out:
#             item            user  rating   timestamp
# 0     0001713353  A1REUF3A1YCPHM     5.0  1112140800
# 1     0001713353   A1YRBRK2XM5D5     5.0  1081036800
# 2     0001713353  A1V8ZR5P78P4ZU     5.0  1077321600
# 3     0001713353  A2ZB06582NXCIV     5.0  1475452800
# 4     0001713353   ACPQVNRD3Z09X     5.0  1469750400
# ...          ...             ...     ...         ...
# 9995  0001844423  A1RZ3DG6SN9ITC     5.0  1437696000
# 9996  0001844423  A2EXJJG1UN0UC8     5.0  1437609600
# 9997  0001844423   A8ZVHTO78LMID     4.0  1437609600
# 9998  0001844423   AZQ76U2XA6NLT     5.0  1437523200
# 9999  0001844423  A2ZJMRY6AJB1EY     5.0  1437523200
#
# [10000 rows x 4 columns]

# %%
book_id = list(subset['item'].unique())
# Out:
# (67,)

# %%
import requests
import pandas as pd

def get_all_book_info_by_isbn(isbn, api_key):
    url = f'https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}&key={api_key}'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['totalItems'] > 0:
            book_info = data['items'][0]['volumeInfo']
            sale_info = data['items'][0].get('saleInfo', {})
            access_info = data['items'][0].get('accessInfo', {})
            # Extracting available information
            # Extracting all available information
            full_info = {
                'ID': isbn,
                'title': book_info.get('title'),
                'authors': book_info.get('authors', 'N/A'),
                'publisher': book_info.get('publisher', 'N/A'),
                'publishedDate': book_info.get('publishedDate', 'N/A'),
                'description': book_info.get('description', 'N/A'),
                'industryIdentifiers': book_info.get('industryIdentifiers', 'N/A'),
                'pageCount': book_info.get('pageCount', 'N/A'),
                'dimensions': book_info.get('dimensions', 'N/A'),
                'printType': book_info.get('printType', 'N/A'),
                'categories': book_info.get('categories', 'N/A'),
                'averageRating': book_info.get('averageRating', 'N/A'),
                'ratingsCount': book_info.get('ratingsCount', 'N/A'),
                'contentVersion': book_info.get('contentVersion', 'N/A'),
                'imageLinks': book_info.get('imageLinks', 'N/A'),
                'language': book_info.get('language', 'N/A'),
                'previewLink': book_info.get('previewLink', 'N/A'),
                'infoLink': book_info.get('infoLink', 'N/A'),
                'canonicalVolumeLink': book_info.get('canonicalVolumeLink', 'N/A'),
                'saleability': sale_info.get('saleability', 'N/A'),
                'isEbook': sale_info.get('isEbook', 'N/A'),
                'listPrice': sale_info.get('listPrice', 'N/A'),
                'retailPrice': sale_info.get('retailPrice', 'N/A'),
                'buyLink': sale_info.get('buyLink', 'N/A'),
                'ebookInfo': access_info.get('epub', 'N/A'),
                'webReaderLink': access_info.get('webReaderLink', 'N/A'),
                'accessViewStatus': access_info.get('accessViewStatus', 'N/A'),
                'quoteSharingAllowed': access_info.get('quoteSharingAllowed', 'N/A')
            }
            return full_info
    # Return an empty dictionary if the request fails or no book is found
    return {}

def get_books_info(book_ids, api_key):
    books_data = []
    for isbn in book_ids:
        book_info = get_all_book_info_by_isbn(isbn, api_key)
        if book_info:  # Only add if book_info is not empty
            books_data.append(book_info)
    return pd.DataFrame(books_data)

# Example usage
api_key = 'AIzaSyDvliA-0qJMm-fDsCc9gaIxaJwoJdbOR4k'  # Replace with your actual Google API key

books_df = get_books_info(book_id, api_key)
books_df
# Out:
#             ID                                              title  \
# 0   0001713353                  The King, the Mice and the Cheese
# 1   0001712799                                   Great Day for Up
# 2   0002005263                                   The Sinister Pig
# 3   000047715X  Mksap 16 Audio Companion: Medical Knowledge Se...
# 4   0001384198                       The Little Engine that Could
# 5   0001381733                         A Child's Garden of Verses
# 6   0000013765                             Heavenly Highway Hymns
# 7   0002008343                                    Cry of the Dove
# 8   0001711296                              Come Over to My House
# 9   0002007649                                     An Apple a Day
# 10  0001472933                                             Daniel
# 11  0001714538                   The Berenstain Bears on the Moon
# 12  0001954563                                The Laughing Dragon
# 13  0001716069                        I Can Lick 30 Tigers Today!
# 14  0002103826       The Collected Short Stories of Louis L'Amour
# 15  0001841572                                          Red Shift
# 16  0001937987                          The Tiger who Came to Tea
# 17  0002007916                                Struck by Lightning
# 18  0002117010                                  Reach for the Sky
# 19  0001840266                  The Four Seasons of Brambly Hedge
# 20  0001983008                                    Paddington Bear
# 21  0001720279                       Hooray for Diffendoofer Day!
# 22  0001720392                                 Green Eggs and Ham
# 23  0001839225                                       Spring Story
# 24  0001713205                 Because a Little Bug Went Ka-choo!
# 25  0001477889                            Second Coming of Christ
# 26  0002111306                        The Companion Guide to Rome
# 27  0001950061                             The Butter Battle Book
# 28  0001921517                                               City
# 29  000211495X                                      Lion and Blue
# 30  0002112256                     Ernest Hemingway; a Life Story
# 31  0002006995                                         Skybreaker
# 32  0002008599                      The Monk Who Sold His Ferrari
# 33  0001840851                               The Secret Staircase
# 34  0001712845       The Berenstain Bears and the Spooky Old Tree
# 35  0001714716                                    The Bear Scouts
# 36  0002007908                                     The Rebel Sell
# 37  0002160595                                        C. S. Lewis
# 38  0002153971                              In the Sewers of Lvov
# 39  000216132X   Civilization and Capitalism, 15th - 18th Century
# 40  0002005018                                       Clara Callan
# 41  0001714384                                 The Very Bad Bunny
# 42  0001945424                                  The Secret Garden
# 43  0002005395                                          Deafening
# 44  0001473123                                         Revelation
# 45  0002163578                                Cry of the Kalahari
# 46  0002005379                                            Airborn
# 47  0001839233                                       Summer Story
# 48  0001857290                                       Charmed Life
#
#                                           authors  \
# 0                     [Nancy Gurney, Eric Gurney]
# 1                                     [Dr. Seuss]
# 2                                [Tony Hillerman]
# 3                                           [Acp]
# 4           [Keith Moseley, Mabel Caroline Bragg]
# 5          [Robert Louis Stevenson, Gyo Fujikawa]
# 6                   [Goodheart-Willcox Publisher]
# 7                                   [Fadia Faqir]
# 8                        [Theo LeSieg, Dr. Seuss]
# 9                                  [Joe Schwarcz]
# 10                   [Rev Clarence Larkin Estate]
# 11              [Stan Berenstain, Jan Berenstain]
# 12                               [Kenneth Mahood]
# 13                                    [Dr. Seuss]
# 14                                [Louis L'Amour]
# 15                                  [Alan Garner]
# 16                                  [Judith Kerr]
# 17                         [Jeffrey S. Rosenthal]
# 18                               [Paul Brickhill]
# 19                                 [Jill Barklem]
# 20                                 [Michael Bond]
# 21        [Dr. Seuss, Jack Prelutsky, Lane Smith]
# 22                                    [Dr. Seuss]
# 23                                 [Jill Barklem]
# 24                     [Rosetta Stone, Dr. Seuss]
# 25                              [Clarence Larkin]
# 26                              [Georgina Masson]
# 27                                    [Dr. Seuss]
# 28                               [David Macaulay]
# 29                   [Robert Vavra, Fleur Cowles]
# 30                                 [Carlos Baker]
# 31                                [Kenneth Oppel]
# 32                           [Robin Shilp Sharma]
# 33                                 [Jill Barklem]
# 34              [Stan Berenstain, Jan Berenstain]
# 35              [Stan Berenstain, Jan Berenstain]
# 36                  [Joseph Heath, Andrew Potter]
# 37          [Roger Lancelyn Green, Walter Hooper]
# 38                              [Robert Marshall]
# 39                              [Fernand Braudel]
# 40                         [Richard Bruce Wright]
# 41                               [Marilyn Sadler]
# 42              [Joyce McAleer, Alison Nicholson]
# 43                                [Frances Itani]
# 44  [Clarence Larkin, Rev Clarence Larkin Estate]
# 45                      [Mark Owens, Delia Owens]
# 46                                [Kenneth Oppel]
# 47                                 [Jill Barklem]
# 48                            [Diana Wynne Jones]
#
#                            publisher publishedDate  \
# 0          Harpercollins Pub Limited    1986-03-01
# 1           HarperCollins Publishers       1982-04
# 2                      HarperCollins          2003
# 3        Oakstone Medical Publishing           N/A
# 4                      HarperCollins          1984
# 5                      HarperCollins          1972
# 6                   Brentwood Benson    1983-08-01
# 7                                N/A    2007-09-13
# 8                            Collins          1967
# 9               Harpercollins Canada          2007
# 10        Rev Clarence Larkin Estate    1990-01-01
# 11         Harpercollins Pub Limited          1985
# 12                     HarperCollins    1970-01-01
# 13          HarperCollins Publishers          1990
# 14                               N/A          2007
# 15  Collins Publishers San Francisco    1973-01-01
# 16                               N/A          1968
# 17              HarperCollins Canada          2005
# 18      London : Companion Book Club          1954
# 19                     HarperCollins          1988
# 20    HarperCollins Children's Books          1998
# 21                     HarperCollins          1998
# 22                     HarperCollins          1999
# 23    HarperCollins Children's Books          1995
# 24                               N/A          2001
# 25        Rev Clarence Larkin Estate    1990-10-01
# 26  Collins Publishers San Francisco          1974
# 27                               N/A          1984
# 28                     HarperCollins          1975
# 29                               N/A       1974-01
# 30                     HarperCollins          1969
# 31                      HarperTrophy    2005-07-31
# 32                               N/A    2007-08-09
# 33    HarperCollins Children's Books          1989
# 34                               N/A          1978
# 35         Harpercollins Pub Limited    1986-07-01
# 36                               N/A          2004
# 37                       HarperAudio          1974
# 38                     HarperCollins          1990
# 39                               N/A          1982
# 40             HarperFlamingo Canada          2001
# 41    HarperCollins Children's Books          1985
# 42                     HarperCollins          1988
# 43               Phyllis Bruce Books    2003-08-18
# 44        Rev Clarence Larkin Estate    1990-01-01
# 45                     HarperCollins          1985
# 46                               N/A          2004
# 47                     HarperCollins       1980-01
# 48                               N/A          2000
#
#                                           description  \
# 0            Lower primary In the style of Dr. Seuss.
# 1                         Synopsis coming soon.......
# 2   Tony Hillerman is a man at the top of his game...
# 3                                                 N/A
# 4                                                 N/A
# 5   A classic collection of Stevenson's childrens ...
# 6                                                 N/A
# 7   The English doctor tells Salma that she must f...
# 8   Children visit many different houses throughou...
# 9   Dr. Schwarcz takes his thorough knowledge of f...
# 10                                                N/A
# 11  When THE BERENSTAIN BEARS GO TO THE MOON young...
# 12  Because he spread flames and destruction when ...
# 13  Pride and overconfidence take many forms. 3 of...
# 14                  A collection of frontier stories.
# 15  SUMMARY: The lives of three young men in three...
# 16                                                N/A
# 17                                                N/A
# 18  Biografi over den fra 2. verdenskrig kendte RA...
# 19  Four stories, originally published separately,...
# 20  The Browns first meet Paddington on a railway ...
# 21  The students of Diffendoofer School celebrate ...
# 22  A nonsensical rhyming story about likes and di...
# 23  Follows the activities of the Brambly Hedge co...
# 24  This title belongs to the highly acclaimed Beg...
# 25  This booklet uses easily understandable charts...
# 26                                                N/A
# 27  "The Butter Battle Book, " Dr. Seuss's classic...
# 28  Superb design, magnificent illustrations, and ...
# 29  A lion searches for the blue Brazilian butterf...
# 30                 The biography of Ernest Hemingway.
# 31  The control car of the giant airship is almost...
# 32  A beautiful 10th anniversary edition of the in...
# 33  Quite by accident, the young mice, Primrose an...
# 34  Three brave little bears have second thoughts ...
# 35  Illus. in full color. "In rollicking rhyme Pap...
# 36  "With the incredible popularity of Michael Moo...
# 37                                                N/A
# 38  Recounts the story of a group of Jews who surv...
# 39                                                N/A
# 40  In a small town in Canada, Clara Callan reluct...
# 41                        Synopsis coming soon.......
# 42                                                N/A
# 43  Deaf since she was five years old, Grania has ...
# 44  This book is illustrated with over 30 charts, ...
# 45  This account of the authors' seven-year stay i...
# 46  Matt Cruse is cabin boy aboard the Aurora, an ...
# 47                     Grade level: 1, 2, 3, k, p, e.
# 48  Gwendolen Chant and her brother Cat find the C...
#
#                                   industryIdentifiers pageCount dimensions  \
# 0   [{'type': 'ISBN_10', 'identifier': '0001713353...        64        N/A
# 1   [{'type': 'ISBN_10', 'identifier': '0001712799...        28        N/A
# 2   [{'type': 'ISBN_10', 'identifier': '0002005263...       228        N/A
# 3   [{'type': 'ISBN_10', 'identifier': '000047715X...       N/A        N/A
# 4   [{'type': 'ISBN_10', 'identifier': '0001384198...         8        N/A
# 5   [{'type': 'ISBN_10', 'identifier': '0001381733...       110        N/A
# 6   [{'type': 'ISBN_10', 'identifier': '0000013765...       N/A        N/A
# 7   [{'type': 'ISBN_10', 'identifier': '0002008343...       304        N/A
# 8   [{'type': 'ISBN_10', 'identifier': '0001711296...        63        N/A
# 9   [{'type': 'ISBN_10', 'identifier': '0002007649...       367        N/A
# 10  [{'type': 'ISBN_10', 'identifier': '0001472933...       N/A        N/A
# 11  [{'type': 'ISBN_10', 'identifier': '0001714538...        38        N/A
# 12  [{'type': 'ISBN_10', 'identifier': '0001954563...        32        N/A
# 13  [{'type': 'ISBN_10', 'identifier': '0001716069...        64        N/A
# 14  [{'type': 'ISBN_10', 'identifier': '0002103826...       438        N/A
# 15  [{'type': 'ISBN_10', 'identifier': '0001841572...       158        N/A
# 16  [{'type': 'ISBN_10', 'identifier': '0001937987...        32        N/A
# 17  [{'type': 'OTHER', 'identifier': 'UVA:X0049082...       280        N/A
# 18  [{'type': 'OTHER', 'identifier': 'STANFORD:361...       406        N/A
# 19  [{'type': 'ISBN_10', 'identifier': '0001840266...         0        N/A
# 20  [{'type': 'ISBN_10', 'identifier': '0001983008...        40        N/A
# 21  [{'type': 'ISBN_10', 'identifier': '0001720279...        54        N/A
# 22  [{'type': 'ISBN_10', 'identifier': '0001720392...         0        N/A
# 23  [{'type': 'ISBN_10', 'identifier': '0001839225...        32        N/A
# 24  [{'type': 'ISBN_10', 'identifier': '0001713205...        30        N/A
# 25  [{'type': 'ISBN_10', 'identifier': '0001477889...        71        N/A
# 26  [{'type': 'OTHER', 'identifier': 'PSU:00001801...       610        N/A
# 27  [{'type': 'ISBN_10', 'identifier': '0001950061...        46        N/A
# 28  [{'type': 'ISBN_10', 'identifier': '0001921517...       112        N/A
# 29  [{'type': 'ISBN_10', 'identifier': '000211495X...        48        N/A
# 30  [{'type': 'OTHER', 'identifier': 'UOM:39015002...       748        N/A
# 31  [{'type': 'ISBN_10', 'identifier': '0002006995...       360        N/A
# 32  [{'type': 'ISBN_10', 'identifier': '0002008599...       224        N/A
# 33  [{'type': 'ISBN_10', 'identifier': '0001840851...         0        N/A
# 34  [{'type': 'ISBN_10', 'identifier': '0001712845...        48        N/A
# 35  [{'type': 'ISBN_10', 'identifier': '0001714716...        64        N/A
# 36  [{'type': 'OTHER', 'identifier': 'STANFORD:361...       376        N/A
# 37  [{'type': 'OTHER', 'identifier': 'UOM:39015038...       330        N/A
# 38  [{'type': 'OTHER', 'identifier': 'UOM:39015019...       240        N/A
# 39  [{'type': 'ISBN_10', 'identifier': '000216132X...       623        N/A
# 40  [{'type': 'ISBN_10', 'identifier': '0002005018...       414        N/A
# 41  [{'type': 'ISBN_10', 'identifier': '0001714384...         0        N/A
# 42  [{'type': 'ISBN_10', 'identifier': '0001945424...        32        N/A
# 43  [{'type': 'ISBN_10', 'identifier': '0002005395...       378        N/A
# 44  [{'type': 'ISBN_10', 'identifier': '0001473123...       N/A        N/A
# 45  [{'type': 'OTHER', 'identifier': 'IND:39000000...       392        N/A
# 46  [{'type': 'ISBN_10', 'identifier': '0002005379...       321        N/A
# 47  [{'type': 'ISBN_10', 'identifier': '0001839233...        32        N/A
# 48  [{'type': 'ISBN_10', 'identifier': '0001857290...       264        N/A
#
#    printType  ...                                canonicalVolumeLink  \
# 0       BOOK  ...  https://books.google.com/books/about/The_King_...
# 1       BOOK  ...  https://books.google.com/books/about/Great_Day...
# 2       BOOK  ...  https://books.google.com/books/about/The_Sinis...
# 3       BOOK  ...  https://books.google.com/books/about/Mksap_16_...
# 4       BOOK  ...  https://books.google.com/books/about/The_Littl...
# 5       BOOK  ...  https://books.google.com/books/about/A_Child_s...
# 6       BOOK  ...  https://books.google.com/books/about/Heavenly_...
# 7       BOOK  ...  https://books.google.com/books/about/Cry_of_th...
# 8       BOOK  ...  https://books.google.com/books/about/Come_Over...
# 9       BOOK  ...  https://books.google.com/books/about/An_Apple_...
# 10      BOOK  ...  https://books.google.com/books/about/Daniel.ht...
# 11      BOOK  ...  https://books.google.com/books/about/The_Beren...
# 12      BOOK  ...  https://books.google.com/books/about/The_Laugh...
# 13      BOOK  ...  https://books.google.com/books/about/I_Can_Lic...
# 14      BOOK  ...  https://books.google.com/books/about/The_Colle...
# 15      BOOK  ...  https://books.google.com/books/about/Red_Shift...
# 16      BOOK  ...  https://books.google.com/books/about/The_Tiger...
# 17      BOOK  ...  https://books.google.com/books/about/Struck_by...
# 18      BOOK  ...  https://books.google.com/books/about/Reach_for...
# 19      BOOK  ...  https://books.google.com/books/about/The_Four_...
# 20      BOOK  ...  https://books.google.com/books/about/Paddingto...
# 21      BOOK  ...  https://books.google.com/books/about/Hooray_fo...
# 22      BOOK  ...  https://books.google.com/books/about/Green_Egg...
# 23      BOOK  ...  https://books.google.com/books/about/Spring_St...
# 24      BOOK  ...  https://books.google.com/books/about/Because_a...
# 25      BOOK  ...  https://books.google.com/books/about/Second_Co...
# 26      BOOK  ...  https://books.google.com/books/about/The_Compa...
# 27      BOOK  ...  https://books.google.com/books/about/The_Butte...
# 28      BOOK  ...  https://books.google.com/books/about/City.html...
# 29      BOOK  ...  https://books.google.com/books/about/Lion_and_...
# 30      BOOK  ...  https://books.google.com/books/about/Ernest_He...
# 31      BOOK  ...  https://books.google.com/books/about/Skybreake...
# 32      BOOK  ...  https://books.google.com/books/about/The_Monk_...
# 33      BOOK  ...  https://books.google.com/books/about/The_Secre...
# 34      BOOK  ...  https://books.google.com/books/about/The_Beren...
# 35      BOOK  ...  https://books.google.com/books/about/The_Bear_...
# 36      BOOK  ...  https://books.google.com/books/about/The_Rebel...
# 37      BOOK  ...  https://books.google.com/books/about/C_S_Lewis...
# 38      BOOK  ...  https://books.google.com/books/about/In_the_Se...
# 39      BOOK  ...  https://books.google.com/books/about/Civilizat...
# 40      BOOK  ...  https://books.google.com/books/about/Clara_Cal...
# 41      BOOK  ...  https://books.google.com/books/about/The_Very_...
# 42      BOOK  ...  https://books.google.com/books/about/The_Secre...
# 43      BOOK  ...  https://books.google.com/books/about/Deafening...
# 44      BOOK  ...  https://books.google.com/books/about/Revelatio...
# 45      BOOK  ...  https://books.google.com/books/about/Cry_of_th...
# 46      BOOK  ...  https://books.google.com/books/about/Airborn.h...
# 47      BOOK  ...  https://books.google.com/books/about/Summer_St...
# 48      BOOK  ...  https://books.google.com/books/about/Charmed_L...
#
#      saleability isEbook listPrice retailPrice buyLink  \
# 0   NOT_FOR_SALE   False       N/A         N/A     N/A
# 1   NOT_FOR_SALE   False       N/A         N/A     N/A
# 2   NOT_FOR_SALE   False       N/A         N/A     N/A
# 3   NOT_FOR_SALE   False       N/A         N/A     N/A
# 4   NOT_FOR_SALE   False       N/A         N/A     N/A
# 5   NOT_FOR_SALE   False       N/A         N/A     N/A
# 6   NOT_FOR_SALE   False       N/A         N/A     N/A
# 7   NOT_FOR_SALE   False       N/A         N/A     N/A
# 8   NOT_FOR_SALE   False       N/A         N/A     N/A
# 9   NOT_FOR_SALE   False       N/A         N/A     N/A
# 10  NOT_FOR_SALE   False       N/A         N/A     N/A
# 11  NOT_FOR_SALE   False       N/A         N/A     N/A
# 12  NOT_FOR_SALE   False       N/A         N/A     N/A
# 13  NOT_FOR_SALE   False       N/A         N/A     N/A
# 14  NOT_FOR_SALE   False       N/A         N/A     N/A
# 15  NOT_FOR_SALE   False       N/A         N/A     N/A
# 16  NOT_FOR_SALE   False       N/A         N/A     N/A
# 17  NOT_FOR_SALE   False       N/A         N/A     N/A
# 18  NOT_FOR_SALE   False       N/A         N/A     N/A
# 19  NOT_FOR_SALE   False       N/A         N/A     N/A
# 20  NOT_FOR_SALE   False       N/A         N/A     N/A
# 21  NOT_FOR_SALE   False       N/A         N/A     N/A
# 22  NOT_FOR_SALE   False       N/A         N/A     N/A
# 23  NOT_FOR_SALE   False       N/A         N/A     N/A
# 24  NOT_FOR_SALE   False       N/A         N/A     N/A
# 25  NOT_FOR_SALE   False       N/A         N/A     N/A
# 26  NOT_FOR_SALE   False       N/A         N/A     N/A
# 27  NOT_FOR_SALE   False       N/A         N/A     N/A
# 28  NOT_FOR_SALE   False       N/A         N/A     N/A
# 29  NOT_FOR_SALE   False       N/A         N/A     N/A
# 30  NOT_FOR_SALE   False       N/A         N/A     N/A
# 31  NOT_FOR_SALE   False       N/A         N/A     N/A
# 32  NOT_FOR_SALE   False       N/A         N/A     N/A
# 33  NOT_FOR_SALE   False       N/A         N/A     N/A
# 34  NOT_FOR_SALE   False       N/A         N/A     N/A
# 35  NOT_FOR_SALE   False       N/A         N/A     N/A
# 36  NOT_FOR_SALE   False       N/A         N/A     N/A
# 37  NOT_FOR_SALE   False       N/A         N/A     N/A
# 38  NOT_FOR_SALE   False       N/A         N/A     N/A
# 39  NOT_FOR_SALE   False       N/A         N/A     N/A
# 40  NOT_FOR_SALE   False       N/A         N/A     N/A
# 41  NOT_FOR_SALE   False       N/A         N/A     N/A
# 42  NOT_FOR_SALE   False       N/A         N/A     N/A
# 43  NOT_FOR_SALE   False       N/A         N/A     N/A
# 44  NOT_FOR_SALE   False       N/A         N/A     N/A
# 45  NOT_FOR_SALE   False       N/A         N/A     N/A
# 46  NOT_FOR_SALE   False       N/A         N/A     N/A
# 47  NOT_FOR_SALE   False       N/A         N/A     N/A
# 48  NOT_FOR_SALE   False       N/A         N/A     N/A
#
#                  ebookInfo                                      webReaderLink  \
# 0   {'isAvailable': False}  http://play.google.com/books/reader?id=T1_iGwA...
# 1   {'isAvailable': False}  http://play.google.com/books/reader?id=12Z0AAA...
# 2   {'isAvailable': False}  http://play.google.com/books/reader?id=l8B3PwA...
# 3   {'isAvailable': False}  http://play.google.com/books/reader?id=vY0cnwE...
# 4   {'isAvailable': False}  http://play.google.com/books/reader?id=0M7NAAA...
# 5   {'isAvailable': False}  http://play.google.com/books/reader?id=_X6LPwA...
# 6   {'isAvailable': False}  http://play.google.com/books/reader?id=eJd-AAA...
# 7   {'isAvailable': False}  http://play.google.com/books/reader?id=rQZMPgA...
# 8   {'isAvailable': False}  http://play.google.com/books/reader?id=plGeQAA...
# 9   {'isAvailable': False}  http://play.google.com/books/reader?id=3JxgPQA...
# 10  {'isAvailable': False}  http://play.google.com/books/reader?id=zFcKAAA...
# 11  {'isAvailable': False}  http://play.google.com/books/reader?id=xO9DOQA...
# 12  {'isAvailable': False}  http://play.google.com/books/reader?id=rSgwPQA...
# 13  {'isAvailable': False}  http://play.google.com/books/reader?id=xKtPGQA...
# 14  {'isAvailable': False}  http://play.google.com/books/reader?id=d-o8uAA...
# 15  {'isAvailable': False}  http://play.google.com/books/reader?id=hSqNSQA...
# 16  {'isAvailable': False}  http://play.google.com/books/reader?id=U0CPPwA...
# 17  {'isAvailable': False}  http://play.google.com/books/reader?id=BXdGAAA...
# 18  {'isAvailable': False}  http://play.google.com/books/reader?id=yPQfAQA...
# 19  {'isAvailable': False}  http://play.google.com/books/reader?id=DN7SAQA...
# 20  {'isAvailable': False}  http://play.google.com/books/reader?id=6Zh48Cz...
# 21  {'isAvailable': False}  http://play.google.com/books/reader?id=g7RCAAA...
# 22  {'isAvailable': False}  http://play.google.com/books/reader?id=9fmWPwA...
# 23  {'isAvailable': False}  http://play.google.com/books/reader?id=xcKZQgA...
# 24  {'isAvailable': False}  http://play.google.com/books/reader?id=xfU_KgA...
# 25  {'isAvailable': False}  http://play.google.com/books/reader?id=NXdRcAA...
# 26  {'isAvailable': False}  http://play.google.com/books/reader?id=iJNZAAA...
# 27  {'isAvailable': False}  http://play.google.com/books/reader?id=WS3XHQA...
# 28  {'isAvailable': False}  http://play.google.com/books/reader?id=wNG2tQE...
# 29  {'isAvailable': False}  http://play.google.com/books/reader?id=FG84AAA...
# 30  {'isAvailable': False}  http://play.google.com/books/reader?id=VSZbAAA...
# 31  {'isAvailable': False}  http://play.google.com/books/reader?id=Vvocj29...
# 32  {'isAvailable': False}  http://play.google.com/books/reader?id=lO2JPwA...
# 33  {'isAvailable': False}  http://play.google.com/books/reader?id=tG7HkQE...
# 34  {'isAvailable': False}  http://play.google.com/books/reader?id=q8_cAAA...
# 35  {'isAvailable': False}  http://play.google.com/books/reader?id=ckOKPwA...
# 36  {'isAvailable': False}  http://play.google.com/books/reader?id=H2aTAAA...
# 37  {'isAvailable': False}  http://play.google.com/books/reader?id=WJDZAAA...
# 38  {'isAvailable': False}  http://play.google.com/books/reader?id=AzpnAAA...
# 39  {'isAvailable': False}  http://play.google.com/books/reader?id=1aWSoAE...
# 40  {'isAvailable': False}  http://play.google.com/books/reader?id=yfx0vgE...
# 41  {'isAvailable': False}  http://play.google.com/books/reader?id=bBs1JAA...
# 42  {'isAvailable': False}  http://play.google.com/books/reader?id=8Xg9PgA...
# 43  {'isAvailable': False}  http://play.google.com/books/reader?id=Vo-GPwA...
# 44  {'isAvailable': False}  http://play.google.com/books/reader?id=hAcCAAA...
# 45  {'isAvailable': False}  http://play.google.com/books/reader?id=VOoHAQA...
# 46  {'isAvailable': False}  http://play.google.com/books/reader?id=bzyVPwA...
# 47  {'isAvailable': False}  http://play.google.com/books/reader?id=vUQqPwA...
# 48  {'isAvailable': False}  http://play.google.com/books/reader?id=m70cKei...
#
#    accessViewStatus quoteSharingAllowed
# 0              NONE               False
# 1              NONE               False
# 2              NONE               False
# 3              NONE               False
# 4              NONE               False
# 5              NONE               False
# 6              NONE               False
# 7              NONE               False
# 8              NONE               False
# 9              NONE               False
# 10             NONE               False
# 11             NONE               False
# 12             NONE               False
# 13             NONE               False
# 14             NONE               False
# 15             NONE               False
# 16             NONE               False
# 17             NONE               False
# 18             NONE               False
# 19             NONE               False
# 20             NONE               False
# 21             NONE               False
# 22             NONE               False
# 23             NONE               False
# 24             NONE               False
# 25             NONE               False
# 26             NONE               False
# 27             NONE               False
# 28             NONE               False
# 29             NONE               False
# 30             NONE               False
# 31             NONE               False
# 32             NONE               False
# 33             NONE               False
# 34             NONE               False
# 35             NONE               False
# 36             NONE               False
# 37             NONE               False
# 38             NONE               False
# 39             NONE               False
# 40             NONE               False
# 41             NONE               False
# 42             NONE               False
# 43             NONE               False
# 44             NONE               False
# 45             NONE               False
# 46             NONE               False
# 47             NONE               False
# 48             NONE               False
#
# [49 rows x 28 columns]
